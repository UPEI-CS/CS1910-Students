# %% [markdown]
# <a href="https://colab.research.google.com/github/cdspower-upei/2026W-CS1910-Full/blob/main/Lectures/wk08/L09-Sequences-Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Indexing and Slicing Strings
# In this lecture students will be introduced to:
# * the concept of sequences as ordered collections of data
# * indexing to access elements by position, including negative indexes
# * identifying and resolving IndexError issues
# * using slicing to extract subsequences with start, end, and step values
# * understanding default behaviours in slicing operation
# * show to traverse strings using loops
# * Python's principle that strings are immutable and what this means for assignment
# * common string methods such as upper(), find(), strip(), and replace() how strings are compared using character ordinal values
# * applying computational thinking to solve sequence-based problems (e.g., the basketball scoring problem)

# %%
#quick hitters

my_string = "Be a friend, pick me up off the ground"

print(my_string[2])
print(my_string[-2])
print((my_string[1]+my_string[-1])[1])
print(my_string[1][0][0][0][0])

# %%
#Slicing Examples
s = "Blueberry"

# Every other character from the whole string
# start at index 0, go to len(s), step by 2
print(s[0:len(s):2])   # 'Bubry'

# Every third character between offsets 2 (inclusive) and 7 (exclusive)
print(s[2:7:3])        # 'ue'

# %%
#Examples of Defaults in Slicing
t = "Charlottetown"

# Reverse the whole string
print(t[::-1])         # 'nwotettolrahC'

# Every second character in reverse, starting from the last character down to index 3 (exclusive)
print(t[:3:-2])        # 'noetl' takes indices len(t)-1, len(t)-3, ... down to > 3

# %%
#self-check

my_string = "sdrawkcab"
for i in range(1, 10):
    print(my_string[-i])

# %%
# Slicing examples

my_string = "Be a friend, pick me up off the ground"

print(my_string[0:1]) #first letter
print(my_string[:1]) #first letter
print(my_string[:11]) #first 11 letters (up to but not including the 11th offset)
print(my_string[-1:]) #last letter
print(my_string[-2:]) #last 2 letters
print(my_string[37:]) #last letter
print(my_string[37:len(my_string)]) #last letter
print(my_string[::2]) #every second letter
print(my_string[::3]) #every 3rd letter
print(my_string[6:12:2]) #every second letter in a slice

# %%
# solution to the basketball problem

game_record = "A2A2A1A1A2A2B2B2B2B1B1B2B2" #B wins the game

# code here to determine and output the winner

# %% [markdown]
# # Traversing the characters of a String
#
# - use a loop

# %%
# example traversals

my_string = "hello, world!"

# for in sequence loop
for char in my_string:
    print(char)

# for in range( ) using [ ] index
for i in range(len(my_string)): # note the use of len(my_string)
    print(my_string[i])

#while loop with [ ] index accessor
count = 0
while count < len(my_string):
    print(my_string[count])
    count += 1

# %%
#String immutability - the [] cannot appear on the left side of an assignment
greeting = "Hello, world!"
# Attempt to replace the first character by assigning into an index
greeting[0] = "Y"

# %%
#String comparison
word = input("Enter a word related to PEI: ")

if word < "Charlottetown":
    print("Your word, " + word + ", comes before Charlottetown.")
elif word > "Charlottetown":
    print("Your word, " + word + ", comes after Charlottetown.")
else:
    print("A perfect match—Charlottetown!")

# %%
# print every 2nd letter in my_string
my_string = "1234567890"

for ch in my_string[::2]:
    print(ch)

for i in range(0,len(my_string),2):
    print(my_string[i])

count = 0
while count < len(my_string):
    print(my_string[count])
    count += 2

# %% [markdown]
# ## String methods

# %%
# a few examples of string methods

my_string = "hello, world!"

#convert to upper case
upper_string = my_string.upper()
print(f"upper: {upper_string}\n")

#convert to lower case
lower = "HELLO".lower()
print(f"lower: {lower}\n")

#find the first occurrence of letter o
index = my_string.find("o")
print(f"found \"o\" at position: {index}")
print(f"letter at that position: {my_string[index]}\n")

#find "or"
index = my_string.find("or")
print("found \"or\" at index: {index}")
print(f"characters at that position: {my_string[index:index+len("or")]}\n")

#find "y"
index = my_string.find("y") #returns -1 when the value is not found
if index == -1:
    print(f"\"y\" not found in \"{my_string}\"\n")

#strip out the leading and trailing whitespace characters
compressed = "    leading and trailing whitespace      ".strip()
print(f"removed whitespace:->{compressed}<-\n")

further_compressed = compressed.replace(" ", "")
print(f"replaced whitespace with empty string:->{further_compressed}<-\n")

# %%
# in operator
if "cat" in "caterpillar":
    print("found it")
else:
    print("oops not found")

# %%
#self check what does this output?

count_str = "01234567890123456789012345678901234567"
my_string = "it's raining, get under my bumbershoot"
my_string.replace("bumbershoot","umbrella")
if "umb" in my_string[18:31:6]:
    print(my_string)

# %% [markdown]
# # Computational Thinking Activities: Basketball 1-on-1 (Win by 2)
#
# **Problem recap**
# - First to 11 points, **must win by 2**.
# - Input: a string of scoring events: `"A2B1A1..."`.
# - Task: Decide whether **A** or **B** wins.
#
# ---
#
# ### Activity A — Abstraction
# **Goal:** Focus on the essential information only.
#
# 1) List the **necessary** details needed to determine a winner:
#    - (bullet list)
#
# 2) List **unnecessary** real‑world details we can ignore in code:
#    - (bullet list)
#
# 3) Propose a **simple representation** for the input and the scores:
#    - Input representation:
#    - Score representation:
#
# ---
#
# ### Activity B — Decomposition
# **Goal:** Break the problem into small steps.
#
# 4) Write the steps that happen each time you read one scoring event:
#    - Step 1:
#    - Step 2:
#    - Step 3:
#
# 5) Write a short checklist your loop can repeat until the game ends:
#    - [ ] Read next event
#    - [ ] Update scores
#    - [ ] Check winner
#    - [ ] Continue or stop
#
# ---
#
# ### Activity C — Logic
# **Goal:** Make the win condition precise.
#
# 6) Fill in the blanks in plain language:
#    “A wins when A has **at least** ____ points **and** the **lead** is at least ____.”
#
# 7) Translate that into simple comparisons we can code (use `>=`, `-`, `abs`):
#    - Condition for A to win:
#    - Condition for B to win:
#
# 8) Why is **reaching 11** not enough to win?
#
# ---
#
# ### Activity D — Pattern Recognition
# **Goal:** Spot useful structure.
#
# 9) What pattern do you notice in the input string (characters and order)?
#    - (one or two sentences)
#
# 10) What repeated pattern can your code rely on after each scoring event?
#    - (one sentence)
#
# ---
#
# ### Activity E — Algorithm Sketch
# **Goal:** Turn your thinking into a step‑by‑step plan.
#
# 11) Write your algorithm in 6–10 short steps (no code yet):
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.
#
# ---
#
# ### Activity F — Validation
# **Goal:** Define test cases before you code.
#
# 12) Create three test sequences:
#    - **Normal quick win** (e.g., A scores 11 straight):
#      Input: __________________   Expected winner: ____
#    - **Another normal win** (e.g., B scores 12 via 2‑pointers):
#      Input: __________________   Expected winner: ____
#    - **Extended play (deuce)** (10–10, then keep going):
#      Input: __________________   Expected winner: ____
#
# 13) Explain **why** the extended play example must continue past 11–10:
#    - (one or two sentences)
#
# ---
#
# ### (Optional) Reflection
# What part of your process helped most: abstraction, decomposition, logic, patterns, algorithm, or validation? Why?

# %% [markdown]
# # Try at Home
#
# - print all of the letters that are in common (same letter in same index position) between two strings
# - beat the simon says game
#       - in simon says: "simon" barks instructions at the contestants but if his instructions do not start with "Simon says" the participate is supposed to do nothing.
#       - example if the instruction is "Simon says do a backflip and land on your head" your program should output "do a backflip and land on your head". If the instruction is "do a backflip and land on your head" your program should output "do nothing"
#
# - print all of the letters from a string in reverse order (one letter on each line) use while and for in sequence loops

# %%
# common letters

string1 = "hullaballoo"
string2 = "honolulu"

#print the letters that are in the same index position in both strings

# %%
# simon says

#instruction

instruction = "Simon says do a backflip" #output should be "do a backflip"
#alternative instruction
#instruction = "open your mouth and yell Simon says" #output should be "do nothing"

#your code here to output the correct action

# %%
# print all of the letters from a string in reverse order

my_string = "Madam, I'm Adam"

#while loop



#for in sequence loop
