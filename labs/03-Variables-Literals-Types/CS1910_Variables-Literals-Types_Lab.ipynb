# %% [markdown]
# <a href="https://colab.research.google.com/github/cdspower-upei/2026W-CS1910-Students/blob/main/Labs/L01/CS1910_Lab01_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS1910 Computer Science 1 - Lab Session**
# # **Python Basics: An Introductory Lab**

# %% [markdown]
# # Getting Started Lab
# Welcome to the Lab Sessions for CS1910! These labs will give you an opportunity to practice some of the skills that you have been reading about in your readings and explore deeper some of the concepts that are discussed in lecture.
#
# For these labs, you should make sure that you have read the sections of the book that are relevant. Each lab is scheduled to happen after the related readings have been assigned, so it will help if you keep up with those throughout the course.

# %% [markdown]
# # Lab Conduct
# In each lab session, you will work with a partner as a pair. Together, you will complete practice activities and answer questions. You may work on a single computer or each type in the same answers on separate adjacent computers.
#
# A Lab Instructor and Lab Assistant will be available to guide and support you throughout the session. The lab is designed to be exploratory — there is nothing to submit. What matters most is that you actively participate and work through all the activities before leaving the lab.
#
# You probably will want a copy of this lab so you can practice and review it. You can get a copy by selecting:
#
# ***File->Save a copy in Drive***
#
# or
#
# ***Copy to Drive*** if it appears in the above menu.
#
# # GenAI in the Notebooks.
# Colab has added GenAI to its notebooks.  While it can be a useful tool for seasoned developers, it is recommended you turn off the Generative AI assitant for the Lab so that you are not tempted to use it.
#
# As discussed in class, simply viewing code does not help you learn it, but instead bypasses your learning.  You can turn it off by going to the gear in the upper right corner near your login and the share button choosing AI Assitance in the dialog box, and then ticking off all of the options.
#
# # Interruptions from Devices
#
# Our world is filled with interuptions. Texts, Discord, Social Media, and more all want our attention.
#
# Programming requires focus and concentration, even when you are really skilled at it. When you are learning, interruptions can pull you away from what is a difficult thing to keep your place in while learning it.  While not mandatory, it is recommended that you put your phones off the desk, and for the labs turn off your notifications.
#
# Students have told us in the past, that when they put these interruptions away, they were able to retain information better about programming, and it took less time to learn.
#
# #Marking of Labs
# Your lab mark is based on your attendance and participating in the lab.  Labs are worth 18\% of your overall course grade.
#
# However, the most important aspect is your attendance and active participation in the lab activities. This is your opportunity to practice.

# %% [markdown]
# # Lab Setup
# This is the usual setup you’ll see in every lab session. When you run the first code block, it will import a set of modules that are libraries. These libraries are needed for the lab to do more complex things more easily than writing it in raw Python. They promote reuse of code among programmers, so that you do not have to write something from scratch when it is something that everyone needs to do like manipulate sets of numbers or display graphics.
#
# Thoughout the lab you will see Show Code. You can click on that text to expand and see the code if you're curious!
# Most of the time, you do not need to show the code. As you move throught the course you will find that you can understand more and more code within those blocks - but a lot of it is quite advanced, so don't worry if you don't understand it right away.

# %%
#@title Run your setup...
#@markdown When you run this block you will either see ✅ SUCCESS or ❌ ERROR <br> letting you know if the library has run correctly. <br><br>
#@markdown If there is an error in this block please talk to your lab instructor for help.


try:
    # Standard library imports
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import ipywidgets as widgets
    import IPython.display as ipd
    import turtle as tt

    import requests
    exec(requests.get('https://raw.githubusercontent.com/cdspower-upei/CS1910-Labs/refs/heads/main/upei-smcs-lablibrary/src/upei_smcs_lablibrary.py').text)



    # Initialize the library for use in lab exercises
    forms = LabFormLibrary()

    print("✅ SUCCESS: All libraries imported successfully!")
    print("✅ Lab Form Library loaded and ready!")
    print("📚 Available form types:")
    print("   • forms.create_info_form() - Information collection")
    print("   • forms.create_question_form() - Q&A with model answers")
    print("   • forms.create_prediction_table() - Code output prediction")
    print("   • forms.create_validation_form() - Truth tables with validation")
    print("   • forms.add_educational_context() - Structured learning context")
    print("   • forms.add_quick_context() - Simple markdown context")
    print("🆕 NEW: All forms now support optional default values!")
    print("You're ready to start the lab!")

except ImportError as e:
    print("❌ ERROR: There was a problem importing the required libraries.")
    print("\n🆘 PLEASE CALL YOUR LAB ASSISTANT FOR HELP")
    print("   They will help you resolve this import issue.")
    print("\n" + "="*50)
    print("🔍 Technical Details (click triangle below to expand):")

    from IPython.display import HTML, display
    display(HTML(f"""
    <details>
    <summary><strong>Click here if you're curious about the error details</strong></summary>
    <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
    ImportError: {e}
    </pre>
    <p><em>Your lab assistant can use these details to help diagnose the problem.</em></p>
    </details>
    """))

except Exception as e:
    print("❌ ERROR: Something unexpected happened during setup.")
    print("\n🆘 PLEASE CALL YOUR LAB ASSISTANT FOR HELP")
    print("   Show them this error message.")
    print("\n" + "="*50)
    print("🔍 Technical Details (click triangle below to expand):")

    from IPython.display import HTML, display
    display(HTML(f"""
    <details>
    <summary><strong>Click here if you're curious about the error details</strong></summary>
    <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
    Error: {e}
    Error Type: {type(e).__name__}
    </pre>
    <p><em>Your lab assistant can use these details to help diagnose the problem.</em></p>
    </details>
    """))

# %%
#@title Group Information
#@markdown In each lab session, you will work with a partner. Please introduce yourself to your partner and record both of your names and emails below. You will do this at the start of every lab.

# Define your data
title = "Group Members Information"
fields = [
    {
        'name': 'member1_name',
        'label': 'Member 1 Name:',
        'placeholder': 'Enter name'
    },
    {
        'name': 'member1_email',
        'label': 'Member 1 Email:',
        'placeholder': 'Enter email'
    },
    {
        'name': 'member2_name',
        'label': 'Member 2 Name:',
        'placeholder': 'Enter name'
    },
    {
        'name': 'member2_email',
        'label': 'Member 2 Email:',
        'placeholder': 'Enter email'
    }
]

# Create and display the form
display_form, get_data = forms.create_info_form(title, fields)
display_form()

# %% [markdown]
# # Lab Conventions
# Each lab has a set of learning objectives listed after the introductory paragraph. These objectives represent the skills and knowledge you will practice in the lab to gain mastery of different topics from CS1910. During the lab, you will encounter activities such as writing statements, coding exercises, and answering questions. Below are some examples of what you will see.

# %% [markdown]
# # Learning Objectives
#
# - Describe differences between program and output text
# - Write assignment statements and use assigned variables
# - identify correctness in assignment statements and variables

# %% [markdown]
# ## 1. Practicing Python Statements
#
# Lab activities may include instructions to write specific statements along with a code cell where you will enter and run those statements.
#
# Below, you will see a few statements they are presented in a `Text cell`. After each statement, there is a `Code cell` where you can write the same statement and run it.
#
# Before typing the statement you should ask your partner what they think the result will be
#
# - statement executes and does this
# - statement fails because ...
#
# After typing the code yourself, press the run button on the left hand side and observe the output of each statement by running the cell - Compare the result against your prediction.
#
# You may encounter some errors when running each statement.  That is part of the learning process. You may also find it interesting to go investigate what those errors mean if they are not self-evident.
#
# Go ahead and try them now.

# %% [markdown]
# #Getting Started with Variables and Assignment
#
# The below line of code is a variable assignment.  The variable data is being given a value 12.
#
# ---
#
#
#
# ```
# data = 12
# ```
# Type the above text directly into the below code cell and press run. You will see there is no output when you run it - it just completes the assignment.

# %% [markdown]
# What do you predict this line of code does?
#
# ---
#
# ```
# data
# ```
# Type the above text directly into the below code cell

# %% [markdown]
# What do you predict this line of code does?  Will it produce the same as the above code block?
#
# ---
#
#
#
# ```
# Data
# ```
# Reflect on what the output was from this code block.  Why did you receive the result you did?

# %% [markdown]
# Reflection: Based on what you have learned about data types - why did that happen?

# %% [markdown]
# Now set the variable Data to be the value 34.
#
# ---
#
#
# ```python
# Data = 34
# ```
# Type the above into the below code cell. What do you expect will be the output?

# %% [markdown]
# Now we will check what *data* stored within it.  Does it have 12 or 34 stored in it?
#
# ---
#
#
# ```python
# data
# ```
# Type the variable name data into the below coding cell to check your answer.

# %% [markdown]
# Given what you have above - what do you think the variable *Data* has in it. What do you think it will produce?
#
# ---
#
#
# ```python
# Data
# ```
#
# Type the variable name *Data* into the below coding cell to check your answer

# %% [markdown]
# #Exploring Variables and Data Assignments
#
# For the next few, repeat what you did above.  Try to predict what you think the output will be.
# * Will a value be printed?
# * Will it output nothing?
# * Will it be an error?
#
# Try to articulate why you think that, and if you do not know, you can look at the notes, readings, or ask your instructor.
#
# Then type each *code snippet* into the code cell below it.
#
# Terminology Alert ⚠️:
# *Code Snippet* - a small piece of code that part of a bigger program that does not do much on its own.
#
# ---
#
# ```
# my data = 56
# ```

# %% [markdown]
# ---
#
#
#
# ```
# my_data = 78
# ```

# %% [markdown]
# ---
#
#
#
# ```
# 3data = "hello"
# ```

# %% [markdown]
# ---
#
#
#
# ```
# data3 = "world"
# ```

# %% [markdown]
# ---
#
#
#
# ```
# data3 = hello
# ```

# %% [markdown]
# ---
#
#
#
# ```
# hot = 273 + 100
# ```

# %% [markdown]
# ---
#
# ```
# 273 + 100 = hot
# ```

# %% [markdown]
# ---
# ```
# hot
# ```

# %% [markdown]
# ---
#
#
#
# ```
# Hot + 100
# ```

# %% [markdown]
# ---
#
#
#
# ```
# hot - 100
# ```

# %%
#@markdown #Checking Your Knowledge

#@markdown Each lab has follow-up questions to help you check your understanding of the material we have done so far in the lab.

#@markdown Run this cell and it will show you a set of questions that you can answer.  When complete, you can select **Submit**.

#@markdown After you have submitted your answers, you can select There is also a **Reveal Answers** option to check your responses.

#@markdown Remember, this is not marked, it is for your own learning.  You are encouraged to not bypass the submission of your answers, because that is how you know what you know and where you need some work.

#@markdown ***Note after you run the block, you may need to scroll up and down to see all the questions / responses, and after your have submitted the Reveal Ansswers button is at the top***.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "number": 1,
        "type": "Submit",
        "question": "Which is the first assignment statement in the above section 1",
        "widget_type": "text"
    },
    {
        "number": 2,
        "type": "Submit",
        "question": "What is the name of the variable being assigned to?",
        "widget_type": "text"
    },
    {
        "number": 3,
        "type": "Submit",
        "question": "What is the the value being assigned to `data` in that first assignment?",
        "widget_type": "text"
    },
    {
        "number": 4,
        "type": "Submit",
        "question": "How many successful assignment statements are in the above section 1?",
        "widget_type": "mulitple_choice",
        "choices": ["0","3","5","7"]
    },
    {
        "number": 5,
        "type": "Submit",
        "question": "After a successful assignment, how can you confirm the value of this variable?",
        "widget_type": "text"
    },
    {
        "number": 6,
        "type": "Submit",
        "question": "[T or F] Variable names in Python can start with a number",
        "widget_type": "multiple_choice",
        "choices" : ["True","False"]
    },
    {
        "number": 7,
        "type": "Submit",
        "question": "[T or F] Variable names in Python must start with a lower case",
        "widget_type": "multiple_choice",
        "choices" : ["True","False"]
    },
    {
        "number": 8,
        "type": "Submit",
        "question": "[T or F] Variable names in Python may not include spaces",
        "widget_type": "multiple_choice",
        "choices" : ["True","False"]
    },
    {
        "number": 9,
        "type": "Submit",
        "question": "[T or F] Variable names in Python are case-sensitive",
        "widget_type": "multiple_choice",
        "choices" : ["True","False"]
    },
    {
        "number": 10,
        "type": "Submit",
        "question": "What is the value of the variable hot after all code is executed from section 1?",
        "widget_type": "submit",
    },
    {
        "number": 11,
        "type": "Submit",
        "question": "Give a line of python code to assign the current value of hot to a new variable cold",
        "widget_type": "submit",
    },
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown
    question_markdown = f"""#### Question {q['number']}:
{q['question']}"""

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(question_markdown))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.RadioButtons(
          options=q["choices"],
          layout=widgets.Layout(
              width='95%',
              max_width='800px',
              margin='0 0 10px 0'
          ),
          style={'description_width': '0px'}
      )

    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            if isinstance(widget.value, tuple) or isinstance(widget.value, list):
              answer = ", ".join(widget.value) if widget.value else "(no answer provided)"
            else:
              answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "data = 12",
        "data",
        "12",
        "5",
        "type the variable name as the last line in a code block and execute",
        "False",
        "False",
        "True",
        "True",
        "373",
        "cold = hot"
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            if isinstance(widget.value, tuple) or isinstance(widget.value, list):
              student_answer = ", ".join(widget.value) if widget.value else "(no answer provided)"
            else:
              student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            correct_answer = answer_key[i]

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# # Predictions with Variables and Types
#
# For the below questions, first discuss then predict the output with you partner.  After you submit, you could actually check your answers precisely and know if they are correct or incorrect.
#
# Don't reveal the answers right away - because you are going to get to tinker to identify what the actual answers are for those prediction.

# %%
#@title Code Prediction Exercise
#@markdown In the labs, you will sometimes be asked to predict specific outputs.  Those outputs can be checked exactly to see if they are right. In the following, you are asked to predict the exact output for the line of code.

#@markdown When you hit **Submit** on this exercise, you will have the option to **Reveal the Answers**.  On these types of exact predictions, you will be told if your answers are right or not.

#@markdown If you are wrong, edit your answers, go back and see if you can work out what should happen.


# STEP 1: Define your code snippets
title = "Code Prediction Exercise"
code_snippets = [
    "print(hello)",
    "print(1)",
    "print(False)",
    "print(int('1'))",
    "print(int('1.5'))",
    "print(int(False))",
    "print(int('True'))",
    "print(str(1.5))",
    "print(str(False))",
    "print(str('True'))",
    "print(int(float('1.5')))"
]

# STEP 2: Define expected answers (optional)
expected_answers = [
    "Error hello not defined",
    "1",
    "False",
    "1",
    "Error int invalid literal '1.5'",
    "0",
    "Error Invald literal 'True'",
    "1.5",
    "False",
    "True",
    "1"
]

# STEP 3: Optional default values (appear as placeholder text)
default_values = [
]

# STEP 4: Create and display the form
display_form = forms.create_prediction_table(title, code_snippets, expected_answers, default_values)
display_form()

# %% [markdown]
# # Practicing Print Statements
#
# For each text cell, code cell combo. Type the python code that is in the text cell into the code cell and run it. Compare the output against your prior prediction.

# %% [markdown]
# ---
# ```python
# print(hello)
# ```

# %% [markdown]
# ---
# ```python
# print(1)
# ```

# %% [markdown]
# ---
# ```python
# print(False)
# ```

# %% [markdown]
# ---
#
# ```python
# print(int('1'))

# %% [markdown]
# ---
#
# ```python
# print(int('1.5'))
# ```

# %% [markdown]
# ---
#
# ```python
# print(int(False))
# ```

# %% [markdown]
# ---
# ```python
# print(int('True'))
# ```

# %% [markdown]
# ---
#
# ```python
# print(str(1.5))
# ```

# %% [markdown]
# ---
# ```python
# print(str(False))
# ```

# %% [markdown]
# ---
# ```python
# print(str('True'))
# ```

# %% [markdown]
# ---
#
# ```python
# print(int(float('1.5')))
# ```

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Finishing Instructions
#
#
# If you would like a copy of this lab - you may choose 1 of 2 options:
#
# 1. File->Save a copy in Drive (each partner would do this). Google sign in is required. You will then be able to open Google Drive from your account later and you will find the file.
#
# or
#
# 2. File->Download .ipynb then you may either email (signing in to a cloud email service) or use a USB key. To later open the notebook in another Colab session you would have to migrate it into your Google Drive account.
#
# Reminder that you can visit the original version of the lab anytime from the course Moodle. It just may not contain information you have typed into cells.
#
# This introductory lab is a little shorter than what you might expect next week, this is to allow a little time for developing comfort within the system and working out any bugs.
#
# If you and your partner are complete you may raise your hand and indicate to the lab instructor that you have finished.
#
# While not mandatory, you are encouraged to use the time to work on your homework assignments or the try at home problems.  If you are done quick, this could be your 20 minutes a day.
