# %% [markdown]
# <a href="https://colab.research.google.com/github/UPEI-CS/CS1910-Students/blob/main/labs/08-Functions/CS1910_Functions_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS1910 Computer Science 1 - Lab Session**
# # **Introduction to Functions**

# %% [markdown]
# # Lab Setup
# When you run the first code block, it will import a set of modules that are libraries. These libraries are needed for the lab to do more complex things more easily than writing it in raw Python. They promote reuse of code among programmers, so that you do not have to write something from scratch when it is something that everyone needs to do like manipulate sets of numbers or display graphics.
#
# Thoughout the lab you will see Show Code. You can click on that text to expand and see the code if you're curious!
# Most of the time, you do not need to show the code. As you move throught the course you will find that you can understand more and more code within those blocks - but a lot of it is quite advanced, so don't worry if you don't understand it right away.
#
# In this lab there are sections labelled "Interactive". In those cases you should open the code block because you will be asked to edit it.

# %%
#@title Run your setup...
#@markdown When you run this block you will either see ✅ SUCCESS or ❌ ERROR <br> letting you know if the library has run correctly. <br><br>
#@markdown If there is an error in this block please talk to your lab instructor for help.


try:
    # Standard library imports
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import ipywidgets as widgets
    import IPython.display as ipd
    import turtle as tt
    import sys, io

    import requests
    exec(requests.get('https://raw.githubusercontent.com/cdspower-upei/CS1910-Labs/refs/heads/main/upei-smcs-lablibrary/src/upei_smcs_lablibrary.py').text)



    # Initialize the library for use in lab exercises
    forms = LabFormLibrary()

    print("✅ SUCCESS: All libraries imported successfully!")
    print("✅ Lab Form Library loaded and ready!")
    print("📚 Available form types:")
    print("   • forms.create_info_form() - Information collection")
    print("   • forms.create_question_form() - Q&A with model answers")
    print("   • forms.create_prediction_table() - Code output prediction")
    print("   • forms.create_validation_form() - Truth tables with validation")
    print("   • forms.add_educational_context() - Structured learning context")
    print("   • forms.add_quick_context() - Simple markdown context")
    print("🆕 NEW: All forms now support optional default values!")
    print("You're ready to start the lab!")

except ImportError as e:
    print("❌ ERROR: There was a problem importing the required libraries.")
    print("\n🆘 PLEASE CALL YOUR LAB ASSISTANT FOR HELP")
    print("   They will help you resolve this import issue.")
    print("\n" + "="*50)
    print("🔍 Technical Details (click triangle below to expand):")

    from IPython.display import HTML, display
    display(HTML(f"""
    <details>
    <summary><strong>Click here if you're curious about the error details</strong></summary>
    <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
    ImportError: {e}
    </pre>
    <p><em>Your lab assistant can use these details to help diagnose the problem.</em></p>
    </details>
    """))

except Exception as e:
    print("❌ ERROR: Something unexpected happened during setup.")
    print("\n🆘 PLEASE CALL YOUR LAB ASSISTANT FOR HELP")
    print("   Show them this error message.")
    print("\n" + "="*50)
    print("🔍 Technical Details (click triangle below to expand):")

    from IPython.display import HTML, display
    display(HTML(f"""
    <details>
    <summary><strong>Click here if you're curious about the error details</strong></summary>
    <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 5px;">
    Error: {e}
    Error Type: {type(e).__name__}
    </pre>
    <p><em>Your lab assistant can use these details to help diagnose the problem.</em></p>
    </details>
    """))

# %%
#@title Group Information
#@markdown Introduce yourself to your partner, and record your names and emails below.

# Define your data
title = "Group Members Information"
fields = [
    {
        'name': 'member1_name',
        'label': 'Member 1 Name:',
        'placeholder': 'Enter name'
    },
    {
        'name': 'member1_email',
        'label': 'Member 1 Email:',
        'placeholder': 'Enter email'
    },
    {
        'name': 'member2_name',
        'label': 'Member 2 Name:',
        'placeholder': 'Enter name'
    },
    {
        'name': 'member2_email',
        'label': 'Member 2 Email:',
        'placeholder': 'Enter email'
    }
]

# Create and display the form
display_form, get_data = forms.create_info_form(title, fields)
display_form()

# %% [markdown]
# ## Lab Introduction
#
# Python programs typically have one or more functions, each of which has one or more statements. Defining new functions allows you to break down a complex program into smaller blocks of reusable code.
#
# ### Learning Objectives
# After completing this session you will be able to:
# - Describe the syntax of function definitions and function calls.
# - Write short functions that have parameters and return results.
# - Summarize the differences between local and global variables.
# - Trace the execution of programs through functions.

# %% [markdown]
# # 1. Defining Functions (10 minutes)
#
# In addition to using Python’s built-in functions and functions defined in the math module, you can write your own functions. In the below, code for function s given. Write the function in following code cell and run it.
#
# ```
# import math
#
# def model_one():
#   angle = float(input("Enter a number: "))
#
#   answer = math.cos(angle)
#   print(answer)
# ```

# %% [markdown]
# The code you have written is called a function definition. The lines following the colon (:) form the body of the function and are automatically indented according to Python’s syntax rules. The code block below shows an example of a function.
#
# At this point, your function is defined. You can now call (i.e., execute) it just like any other function, as shown in the following code snippet to the code cell. Then, run the code cell and observe the output
#
#
# ```
# model_one()
# ```

# %% [markdown]
# At this point, your function is defined. You can *call* (i.e., run) it like other functions. Copy the above function call into the below cell to run the function:

# %%
#@title 1.1 Check Your Understanding From Function Defination
#@markdown Since you have already defined and called a function, you now have a good understanding of function definition and invocation.
#@markdown Based on this, let’s continue with the following questions.

#@markdown When you run this cell, the questions will be displayed along with a space where you can write your answer.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "number": 1,
        "type": "Submit",
        "question": "What is the output displayed on the screen after calling the `model_one` function? When asked, enter the number `0` as input.",
        "widget_type": "text"
    },
    {
        "number": 2,
        "type": "Submit",
        "question": "The variable answer exists inside the `model_one` function",
        "widget_type": "multiple_choice",
        "choices": ["Yes.","No."]
    },
    {
        "number": 3,
        "type": "Submit",
        "question": "The variable answer exists outside the `model_one` function",
        "widget_type": "multiple_choice",
        "choices": ["Yes.","No."]
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown
    question_markdown = f"""#### Question {q['number']}:
{q['question']}"""

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(question_markdown))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.RadioButtons(
          options=q["choices"],
          layout=widgets.Layout(
              width='95%',
              max_width='800px',
              margin='0 0 10px 0'
          ),
          style={'description_width': '0px'}
      )
    elif q["widget_type"] == "checkbox":
      widget = widgets.SelectMultiple(
        options=q["choices"],
        description='Select:',
        disabled=False,
        layout=widgets.Layout(width='95%', max_width='1800px', margin='0 0 10px 0'),
        style={'description_width': '0px'}
      )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Function Defination Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "1.0",
        "Yes. the value of answer is displayed with the print",
        "No. NameError: name ’answer’ is not defined"
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY - Function Defination Questions:")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# ## 1.2 Write the code
#
# Type the three statements of model_one manually into the following code block. (We assume you typed import math earlier, but if you didn’t, do that first.) You should get the same output as the output of the previous code block, without calling the function. Then retype the last line simply as answer without calling print.

# %%
#@title Answer the Following Question Based on Your Code
#@markdown Does the output from the above cell differ from the result of the previous function definition and call? Explain why or why not.

#@markdown When you run this cell, a space will be displayed along where you can write your answer.


import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "number": 1,
        "type": "Submit",
        "question": "Does the output differ between the individual lines of code above and the function call?",
        "widget_type": "text"
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(q["question"]))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "No, the answer is the same. Calling print is unnecessary in the console, because it prints the value of the last line automatically."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# Define the `model_one` function again (retype the `def` code), but this time
# make the last line simply answer with no print. Call the `model_one` function
# again.

# %%
#@title Answer the Following Question Based on Your Code
#@markdown Which of the following options is true regarding the function output?

#@markdown When you run this cell, a space will be displayed along where you can write your answer.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "type": "Submit",
        "question": "Which of the following is true?",
        "widget_type": "multiple_choice",
        "choices": ["Executing a code block containing a function definition is the same as executing the individual lines of the function.", "Executing a Function definition produces output, but it is different than executing the lines separately.", "A function definition does not do anything until it is called."]
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown

    question_display = widgets.Output()


    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.RadioButtons(
          options=q["choices"],
          layout=widgets.Layout(
              width='95%',
              max_width='800px',
              margin='0 0 10px 0'
          ),
          style={'description_width': '0px'}
      )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "A function definition does not do anything until it is called."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# # 2. Passing Arguments(15 minutes)
#
# Alternatively to using `input` inside a function, we can define a function that takes a *parameter*.
#
# When we pass information into a function, there is an *implied* assignment of the *value* of the argument, provided when the function is called, to the parameter.
#
# Type the following definition in the following code cell. (If you are using a new console window, you will need to import math again first.)
#
# ```
# def model_two(angle):
#   print("angle =", angle)
#   answer = math.cos(angle)
#   print(answer)
# ```

# %% [markdown]
# When we call the `model_two` function, we must provide an *argument* for the `angle` parameter. In general, arguments are values that get assigned to parameters automatically. To see how this function works, run the following statements in the corresponding code cells.

# %% [markdown]
# ```
# model_two()
# ```

# %% [markdown]
# ```
# model_two(5)
# ```

# %% [markdown]
# ```
# dozen = 12
# ```

# %% [markdown]
# ```
# model_two(dozen)
# ```

# %% [markdown]
# In this exercise, you will answer a few questions about functions with arguements.

# %%
#@title 2.1 Apply Your Knowledge On Arguments in Functions
#@markdown You have written a function with parameters and invoked it using arguments.
#@markdown This means you now understand how to define a parameterized function and how to call it.
#@markdown Now, Answer the following questions:

#@markdown When you run this cell, a space will be displayed along where you can write your answer.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "number": 1,
        "type": "Submit",
        "question": "What is the argument in the first successful `model_two` function call?",
        "widget_type": "text"
    },
    {
        "number": 2,
        "type": "Submit",
        "question": "What is the value of the parameter in the first successful `model_two` function call?",
        "widget_type": "text"
    },
    {
        "number": 3,
        "type": "Submit",
        "question": "What is the argument in the second successful `model_two` function call?",
        "widget_type": "text"
    },
    {
        "number": 4,
        "type": "Submit",
        "question": "What is the value of the parameter in the second successful `model_two` function call?",
        "widget_type": "text"
    },
    {
        "number": 5,
        "type": "Submit",
        "question": "When a variable is used as an argument, does the name of the variable need to be the same as the parameter variable name?",
        "widget_type": "multiple_choice",
        "choices": ["Yes.","No."]
    },
    {
        "number": 6,
        "type": "Submit",
        "question": "What is the argument in the function call `model_two(1-1)`?",
        "widget_type": "text"
    },
    {
        "number": 7,
        "type": "Submit",
        "question": "What is the value of the parameter in the function call `model_two(1-1)`?",
        "widget_type": "text"
    },
    {
        "number": 8,
        "type": "Self-Check",
        "question": "Calling `model_two( )` has an implied assignment statement. What exactly gets “passed” when calling the function?",
        "widget_type": "textarea"
    }

]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown
    question_markdown = f"""#### Question {q['number']}:
{q['question']}"""

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(question_markdown))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.RadioButtons(
          options=q["choices"],
          layout=widgets.Layout(
              width='95%',
              max_width='800px',
              margin='0 0 10px 0'
          ),
          style={'description_width': '0px'}
      )
    elif q["widget_type"] == "checkbox":
      widget = widgets.SelectMultiple(
        options=q["choices"],
        description='Select:',
        disabled=False,
        layout=widgets.Layout(width='95%', max_width='1800px', margin='0 0 10px 0'),
        style={'description_width': '0px'}
      )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Arguments in Functions Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "5 (the literal)",
        "5",
        "dozen (the variable)",
        "12",
        "No",
        "1 - 1 (the expression)",
        "0",
        "The value of the argument is passed; it gets assigned to the parameter. Note that the argument itself is not passed."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY - Arguments in Functions Questions:")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# # 3. Returning Values
#
# Functions may optionally use a `return` statement to send a value back to where the function was called. Type the following program definition in the following code cell.
#
# ```
# def model_three(angle):
#   print("angle =", angle)
#   answer1 = math.cos(angle)
#   answer2 = math.cos(angle * angle)
#   print(answer1, answer2)
#   return answer2
# ```

# %% [markdown]
# To investigate how this function works: for each statement below re-enter and run it in the code cell immediately following it

# %% [markdown]
# ```
# model_three(5)
# ```

# %% [markdown]
# ```
# answer1
# ```

# %% [markdown]
# ```
# answer2
# ```

# %% [markdown]
# ```
# result = model_three(5)
# ```

# %% [markdown]
# ```
# result
# ```

# %% [markdown]
# ```
# result / 100
# ```

# %%
#@title 3.1 Test Your Understanding on `return` Statement
#@markdown You have now learned how to use the `return` statement in functions.
#@markdown This means you understand how a function can send back a value to the caller.
#@markdown Now, Answer the following questions:

#@markdown When you run this cell, a space will be displayed along where you can write your answer.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "number": 1,
        "type": "Submit",
        "question": "Do the variables `answer1` and `answer2` exist inside of the `model_three` function?",
        "widget_type": "multiple_choice",
        "choices": ["Yes.","No."]
    },
    {
        "number": 2,
        "type": "Submit",
        "question": "Do the variables `answer1` and `answer2` exist outside the `model_three` function?",
        "widget_type": "multiple_choice",
        "choices": ["Yes.","No."]
    },
    {
        "number": 3,
        "type": "Submit",
        "question": "Does result get its value from `answer1` or `answer2` ",
        "widget_type": "multiple_choice",
        "choices": ["answer1.","answer2."]
    },
    {
        "number": 4,
        "type": "Self-Check",
        "question": "Is it possible to perform an operation involving the value of `answer2` and not `answer1` after the function call?",
        "widget_type": "textarea"
    },
    {
        "number": 5,
        "type": "Self-Check",
        "question": "Explain why a function that returns the value of a variable is more useful than a function that simply prints the value of a variable.",
        "widget_type": "textarea"
    },
    {
        "number": 6,
        "type": "Self-Check",
        "question": "Define the model_three function again (retype the def code), but this time reverse the last two lines (return then print). What does the output suggest about the `return` statement?",
        "widget_type": "textarea"
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown
    question_markdown = f"""#### Question {q['number']}:
{q['question']}"""

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(question_markdown))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.RadioButtons(
          options=q["choices"],
          layout=widgets.Layout(
              width='95%',
              max_width='800px',
              margin='0 0 10px 0'
          ),
          style={'description_width': '0px'}
      )
    elif q["widget_type"] == "checkbox":
      widget = widgets.SelectMultiple(
        options=q["choices"],
        description='Select:',
        disabled=False,
        layout=widgets.Layout(width='95%', max_width='1800px', margin='0 0 10px 0'),
        style={'description_width': '0px'}
      )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted `return` Statement Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "yes; they store the results from math.cos",
        "NameError: name ’answer1’ is not defined",
        "The return value is from answer2.",
        "Both variables cease to exist after the function call. However, the value of answer2 is returned (assigned) to the variable result.",
        "Printing a value to the screen only benefits the user in that moment. If you instead return the value, you can continue to use it in the program.",
        "This time answer1 and answer2 are not printed. The return statement immediately goes back to the function call; any remaining statements in the function are not executed."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY - `return` Statement Questions:")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"\n Question {q['number']}:")
            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# # 4. Local vs Global
#
# ## Overview of exercise:
# Variables that are assigned within a function are known as `local variables` in the local scope. Variables that are assigned outside all functions are known as `global variables` in the global scope.
#
#
# Given the below piece of code (do not run the code), we will do the this exercises.

# %%
def one():
  print("one:", x)

def two():
  x = 456
  print("two:", x)

def foo(x):
  x = 789
  print("two:", x)

x = 123
one()
two()
print("after two:", x)
foo(x)
print("after foo:", x)

# %%
#@title 4.1 Label each variable `x` in the above as *local* or *global*.

#@markdown When you run this cell, a space will be displayed along where you can write your answer.

import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "type": "Submit",
        "question": "Line 2",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 5",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 6",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 9",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 10",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 12",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 15",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 16",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    },
    {
        "type": "Submit",
        "question": "Line 17",
        "widget_type": "multiple_choice",
        "choices": ["local.","global."]
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown
    question_markdown = f"""#### {q['question']}"""

    question_display = widgets.Output()
    with question_display:
        ipd.display(ipd.Markdown(question_markdown))

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    elif q["widget_type"] == "multiple_choice":
      widget = widgets.ToggleButtons(
          options=q["choices"],
          layout=widgets.Layout(width='200px', justify_content='flex-start'),
          style={'description_width': '0px'}
      )
    elif q["widget_type"] == "checkbox":
      widget = widgets.SelectMultiple(
        options=q["choices"],
        description='Select:',
        disabled=False,
        layout=widgets.Layout(width='95%', max_width='1800px', margin='0 0 10px 0'),
        style={'description_width': '0px'}
      )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.HBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted `local` or `global` Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"{q['question']}")
            print(f"A: {answer}")
            print("-" * 60)
        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY - `local` or `global` Questions:")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"

            print(f"{q['question']}")
            print(f"Your Answer: {student_answer}")


        print(f"Model Answer: The x’s in two() and foo() should be local. All other x’s should be global.")
        print("-" * 100)
        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %%
#@title 4.2 Predict the Numeric Output
#@markdown To explore how the `one` `two` `foo` functions work, write down the expected output of each statement.
#@markdown Imagine this program runs **one line at a time**—so when making your predictions, assume that all previous lines have already been executed.

#@markdown When you run this cell, a space will be displayed along where you can write your answer.
# Define your data
title = "Numeric Output Prediction"
code_snippets = [
    "one()",
    "two()",
    "print('after two: ', x)",
    "foo(x)",
    "print('after foo: ', x)"
]

# Expected answers for reveal functionality
expected_answers = [
    "123",
    "456",
    "123",
    "789",
    "123",
]


# Create and display the form
display_form = forms.create_prediction_table(title, code_snippets, expected_answers)
display_form()

# %% [markdown]
# ## 4.3  Write the code
# Now that you’ve made your predictions, write each program in the code cell below and run it to compare your predicted output with the actual result.

# %% [markdown]
# ```
# def one():
#   print("one:", x)
#
# def two():
#   x = 456
#   print("two:", x)
#
# def foo(x):
#   x = 456
#   print("two:", x)
# ```

# %% [markdown]
# ```
# x = 123
# ```

# %% [markdown]
# ```
# one()
# ```

# %% [markdown]
# ```
# two()
# ```

# %% [markdown]
# ```
# print("after two:", x)
# ```

# %% [markdown]
# ```
# foo(x)
# ```

# %% [markdown]
# ```
# print("after foo:", x)
# ```

# %%
#@title Explain any unexpected results you observed between your prediction and actual result.

#@markdown When you run this cell, a space will be displayed along where you can write your answer.
import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "type": "Submit",
        "question": "Which of the following is true?",
        "widget_type": "text"
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown

    question_display = widgets.Output()

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            print(f"Q: {q['question']}")
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "Inside a function. Values are not automatically printed."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"Q: {q['question']}")
            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %% [markdown]
# Now that you have written some code to demonstrate the difference and explored the concepts of local and global variables, write each program in the code cell below and then answer the questions that follow.

# %% [markdown]
# ```
# def apple():
#   print("one:", x)
#
# def orange():
#   x = 456
#   print("two:", x)
#
# def pineaple(x):
#   x = 456
#   print("two:", x)
#
# ```

# %% [markdown]
# ```
# apple()
# ```

# %% [markdown]
# ```
# x = 123
# ```

# %% [markdown]
# ```
# orange()
# ```

# %% [markdown]
# ```
# print("after two:", x)
# ```

# %% [markdown]
# ```
# pineaple(x)
# ```

# %% [markdown]
# ```
# print("after foo:", x)
# ```

# %%
#@title Explain the result, you have observed running each code cell.

#@markdown When you run this cell, a space will be displayed along where you can write your answer.
import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "type": "Submit",
        "widget_type": "text"
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown

    question_display = widgets.Output()

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "NameError: name ’x’ is not defined. When the one() function is called, the global variable x has not yet been assigned."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)

# %%
#@title Why should you avoid using global variables in programs that define functions?

#@markdown When you run this cell, a space will be displayed along where you can write your answer.
import ipywidgets as widgets
import IPython.display as ipd

# Question data
questions = [
    {
        "type": "Submit",
        "widget_type": "text"
    }
]

# Create answer widgets for questions
answer_widgets = []
question_containers = []

for i, q in enumerate(questions):
    # Create question header using markdown

    question_display = widgets.Output()

    # Create appropriate widget based on type
    if q["widget_type"] == "textarea":
        widget = widgets.Textarea(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                height='80px',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )
    else:  # text
        widget = widgets.Text(
            placeholder='Enter your answer here...',
            layout=widgets.Layout(
                width='95%',
                max_width='800px',
                margin='0 0 10px 0'
            ),
            style={'description_width': '0px'}
        )

    answer_widgets.append(widget)

    # Create container for this question
    question_container = widgets.VBox([
        question_display,
        widget
    ], layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 25px 0'
    ))

    question_containers.append(question_container)

# Submit and Edit buttons
submit_button = widgets.Button(
    description='Submit All Answers',
    button_style='success',
    layout=widgets.Layout(width='200px', margin='10px 5px 0 0')
)

edit_button = widgets.Button(
    description='Edit Answers',
    button_style='warning',
    layout=widgets.Layout(width='150px', margin='10px 5px 0 0')
)

# Reveal answers button
reveal_button = widgets.Button(
    description='Reveal Answers',
    button_style='info',
    layout=widgets.Layout(width='150px', margin='10px 0 0 0')
)

# Output area for displaying submitted answers
output_area = widgets.Output()

def submit_answers(button):
    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Submitted Questions:")
        print("=" * 80)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            print(f"A: {answer}")
            print("-" * 60)

        print("\n✅ All answers saved! You can edit them anytime using the 'Edit Answers' button.")

    # Hide form and show edit/reveal buttons
    form_container.layout.display = 'none'
    submit_button.layout.display = 'none'
    edit_button.layout.display = 'block'
    reveal_button.layout.display = 'block'

def edit_answers(button):
    # Show form and hide edit/reveal buttons
    form_container.layout.display = 'block'
    submit_button.layout.display = 'block'
    edit_button.layout.display = 'none'
    reveal_button.layout.display = 'none'

    with output_area:
        ipd.clear_output(wait=True)
        print("📝 Edit mode activated - make your changes and click 'Submit All Answers' again.")

def reveal_answers(button):
    # Answer key for all questions
    answer_key = [
        "To avoid errors – it’s unclear what the value of the variable is in the function. Instead of global variables, you should use parameters for passing data around."
    ]

    with output_area:
        ipd.clear_output(wait=True)
        print("📚 ANSWER KEY :")
        print("=" * 100)

        for i, (q, widget) in enumerate(zip(questions, answer_widgets)):
            student_answer = widget.value.strip() if widget.value.strip() else "(no answer provided)"
            correct_answer = answer_key[i]

            print(f"Your Answer: {student_answer}")
            print(f"Model Answer: {correct_answer}")
            print("-" * 100)

        print("\n📝 Note: These are model answers. Your responses may vary in wording")
        print("while still demonstrating correct understanding of the concepts.")

# Connect button functions
submit_button.on_click(submit_answers)
edit_button.on_click(edit_answers)
reveal_button.on_click(reveal_answers)

# Initially hide edit and reveal buttons
edit_button.layout.display = 'none'
reveal_button.layout.display = 'none'

# Create main containers
form_container = widgets.VBox(
    question_containers,
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='0 0 0 0'
    )
)

button_container = widgets.HBox(
    [submit_button, edit_button, reveal_button],
    layout=widgets.Layout(
        width='95%',
        max_width='800px',
        margin='10px 0 0 0'
    )
)

# Display everything at once to prevent scrolling
all_content = widgets.VBox([
    form_container,
    button_container,
    output_area
], layout=widgets.Layout(
    width='95%',
    max_width='800px',
    margin='0 0 0 0'
))

ipd.display(all_content)
